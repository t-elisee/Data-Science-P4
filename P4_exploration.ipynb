# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
import missingno as msno
import json
from pandas.io.json import json_normalize

# %%
df_2016 = pd.read_csv('C:/Users/Elisée/Desktop/P4/2016-building-energy-benchmarking.csv')
df_2015 = pd.read_csv('C:/Users/Elisée/Desktop/P4/2015-building-energy-benchmarking.csv')

# %% [markdown]
# #### Faire une copie des dataframes

# %%
df_2016 = df_2016.copy()
df_2015 = df_2015.copy()

# %%
pd.read_json('C:/Users/Elisée/Desktop/P4/socrata_metadata_2015-building-energy-benchmarking.json', lines=True)
# Out:
#           id                               name assetType      attribution  \
# 0  h7rm-fz6m  2015 Building Energy Benchmarking   dataset  City of Seattle
#
#                       attributionLink  averageRating   createdAt  \
# 0  http://www.seattle.gov/environment              0  1492461362
#
#                                          description displayType  \
# 0  Seattle’s Building Energy Benchmarking and Rep...       table
#
#    downloadCount  hideFromCatalog  hideFromDataJson  indexUpdatedAt  \
# 0           2851            False             False      1551379229
#
#        licenseId  newBackend  numberOfComments       oid provenance  \
# 0  PUBLIC_DOMAIN        True                 0  28249767   official
#
#    publicationAppendEnabled  publicationDate  publicationGroup  \
# 0                     False       1521489624          14152737
#
#   publicationStage  rowsUpdatedAt rowsUpdatedBy   tableId  totalTimesRated  \
# 0        published     1521489255     9yyf-ecsx  14945997                0
#
#    viewCount  viewLastModified viewType  \
# 0       4797        1557955129  tabular
#
#                                            approvals  \
# 0  [{'reviewedAt': 1521489624, 'reviewedAutomatic...
#
#                                              columns  \
# 0  [{'id': 350402298, 'name': 'OSEBuildingID', 'd...
#
#                                               grants  \
# 0  [{'inherited': False, 'type': 'viewer', 'flags...
#
#                      license  \
# 0  {'name': 'Public Domain'}
#
#                                             metadata  \
# 0  {'rdfSubject': '0', 'jsonQuery': {'order': [{'...
#
#                                                owner  \
# 0  {'id': '9yyf-ecsx', 'displayName': 'Sullivan, ...
#
#                                                query  rights  \
# 0  {'orderBys': [{'ascending': True, 'expression'...  [read]
#
#                                          tableAuthor  \
# 0  {'id': '9yyf-ecsx', 'displayName': 'Sullivan, ...
#
#                                                 tags  \
# 0  [building, eui, benchmarking, energy, electric...
#
#                                                flags
# 0  [default, ownerMayBeContacted, restorable, res...

# %%
pd.read_json('C:/Users/Elisée/Desktop/P4/socrata_metadata_2016-building-energy-benchmarking.json', lines=True)
# Out:
#           id                               name assetType      attribution  \
# 0  2bpz-gwpy  2016 Building Energy Benchmarking   dataset  City of Seattle
#
#                               attributionLink  averageRating   createdAt  \
# 0  https://www.seattle.gov/energybenchmarking              0  1521070051
#
#                                          description displayType  \
# 0  Seattle’s Building Energy Benchmarking and Rep...       table
#
#    downloadCount  hideFromCatalog  hideFromDataJson  indexUpdatedAt  \
# 0           2301            False             False      1521490072
#
#        licenseId  newBackend  numberOfComments       oid provenance  \
# 0  PUBLIC_DOMAIN        True                 0  28218043   official
#
#    publicationAppendEnabled  publicationDate  publicationGroup  \
# 0                     False       1521071079          14936543
#
#   publicationStage  rowIdentifierColumnId  rowsUpdatedAt rowsUpdatedBy  \
# 0        published              349768636     1521071078     9yyf-ecsx
#
#     tableId  totalTimesRated  viewCount  viewLastModified viewType  \
# 0  14936543                0       2896        1557954938  tabular
#
#                                            approvals  \
# 0  [{'reviewedAt': 1521071079, 'reviewedAutomatic...
#
#                                              columns  \
# 0  [{'id': 349768636, 'name': 'OSEBuildingID', 'd...
#
#                                               grants  \
# 0  [{'inherited': False, 'type': 'viewer', 'flags...
#
#                      license  \
# 0  {'name': 'Public Domain'}
#
#                                             metadata  \
# 0  {'sidebar': {'width': 482}, 'custom_fields': {...
#
#                                                owner query  rights  \
# 0  {'id': '9yyf-ecsx', 'displayName': 'Sullivan, ...    {}  [read]
#
#                                          tableAuthor  \
# 0  {'id': '9yyf-ecsx', 'displayName': 'Sullivan, ...
#
#                                                 tags  \
# 0  [building, eui, energy, steam, electricity, gr...
#
#                                                flags
# 0  [default, ownerMayBeContacted, restorable, res...

# %% [markdown]
# #### Vu d'ensemble

# %%
df_2015.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# 2  {'latitude': '47.61334897', 'longitude': '-122...                    7
# 3  {'latitude': '47.61421585', 'longitude': '-122...                    7
# 4  {'latitude': '47.6137544', 'longitude': '-122....                    7
#
#   Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 0     DOWNTOWN       1927                  1            12.0
# 1     DOWNTOWN       1996                  1            11.0
# 2     DOWNTOWN       1969                  1            41.0
# 3     DOWNTOWN       1926                  1            10.0
# 4     DOWNTOWN       1980                  1            18.0
#
#    PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 0             88434                   0                   88434
# 1            103566               15064                   88502
# 2            961990                   0                  961990
# 3             61320                   0                   61320
# 4            119890               12460                  107430
#
#        ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 0                          Hotel                  Hotel
# 1     Hotel, Parking, Restaurant                  Hotel
# 2  Hotel, Parking, Swimming Pool                  Hotel
# 3                          Hotel                  Hotel
# 4  Hotel, Parking, Swimming Pool                  Hotel
#
#    LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0                    88434.0                          NaN
# 1                    83880.0                      Parking
# 2                   757243.0                      Parking
# 3                    61320.0                          NaN
# 4                   123445.0                      Parking
#
#    SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                              NaN                         NaN
# 1                          15064.0                  Restaurant
# 2                         100000.0               Swimming Pool
# 3                              NaN                         NaN
# 4                          68009.0               Swimming Pool
#
#    ThirdLargestPropertyUseTypeGFA YearsENERGYSTARCertified  ENERGYSTARScore  \
# 0                             NaN                      NaN             65.0
# 1                          4622.0                      NaN             51.0
# 2                             0.0                      NaN             18.0
# 3                             NaN                      NaN              1.0
# 4                             0.0                      NaN             67.0
#
#    SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  \
# 0              78.9                80.3               173.5
# 1              94.4                99.0               191.3
# 2              96.6                99.7               242.7
# 3             460.4               462.5               636.3
# 4             120.1               122.1               228.8
#
#    SourceEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# 0                 175.1            6981428.0              7097539.0
# 1                 195.2            8354235.0              8765788.0
# 2                 246.5           73130656.0             75506272.0
# 3                 643.2           28229320.0             28363444.0
# 4                 227.1           14829099.0             15078243.0
#
#    SteamUse(kBtu)  Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 0       2023032.0         1080307.0          3686160.0             12724.0
# 1             0.0         1144563.0          3905411.0             44490.0
# 2      19660404.0        14583930.0         49762435.0             37099.0
# 3      23458518.0          811521.0          2769023.0             20019.0
# 4             0.0         1777841.0          6066245.0             87631.0
#
#    NaturalGas(kBtu)  OtherFuelUse(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 0         1272388.0                 0.0                        249.43
# 1         4448985.0                 0.0                        263.51
# 2         3709900.0                 0.0                       2061.48
# 3         2001894.0                 0.0                       1936.34
# 4         8763105.0                 0.0                        507.70
#
#    GHGEmissionsIntensity(kgCO2e/ft2) DefaultData Comment ComplianceStatus  \
# 0                               2.64          No     NaN        Compliant
# 1                               2.38          No     NaN        Compliant
# 2                               1.92         Yes     NaN        Compliant
# 3                              31.38          No     NaN        Compliant
# 4                               4.02          No     NaN        Compliant
#
#         Outlier  2010 Census Tracts  \
# 0           NaN                 NaN
# 1           NaN                 NaN
# 2           NaN                 NaN
# 3  High Outlier                 NaN
# 4           NaN                 NaN
#
#    Seattle Police Department Micro Community Policing Plan Areas  \
# 0                                               14.0
# 1                                               14.0
# 2                                               56.0
# 3                                               56.0
# 4                                               56.0
#
#    City Council Districts  SPD Beats  Zip Codes
# 0                     NaN       31.0      18081
# 1                     NaN       31.0      18081
# 2                     NaN       31.0      18081
# 3                     NaN       31.0      18081
# 4                     NaN       31.0      19576

# %%
df_2016.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# 0                    0659000030                    7     DOWNTOWN  47.61220
# 1                    0659000220                    7     DOWNTOWN  47.61317
# 2                    0659000475                    7     DOWNTOWN  47.61393
# 3                    0659000640                    7     DOWNTOWN  47.61412
# 4                    0659000970                    7     DOWNTOWN  47.61375
#
#    Longitude  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0 -122.33799       1927                1.0              12             88434
# 1 -122.33393       1996                1.0              11            103566
# 2 -122.33810       1969                1.0              41            956110
# 3 -122.33664       1926                1.0              10             61320
# 4 -122.34047       1980                1.0              18            175580
#
#    PropertyGFAParking  PropertyGFABuilding(s)      ListOfAllPropertyUseTypes  \
# 0                   0                   88434                          Hotel
# 1               15064                   88502     Hotel, Parking, Restaurant
# 2              196718                  759392                          Hotel
# 3                   0                   61320                          Hotel
# 4               62000                  113580  Hotel, Parking, Swimming Pool
#
#   LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 0                  Hotel                    88434.0
# 1                  Hotel                    83880.0
# 2                  Hotel                   756493.0
# 3                  Hotel                    61320.0
# 4                  Hotel                   123445.0
#
#   SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 0                          NaN                              NaN
# 1                      Parking                          15064.0
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                      Parking                          68009.0
#
#   ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 0                         NaN                             NaN
# 1                  Restaurant                          4622.0
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4               Swimming Pool                             0.0
#
#   YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                      NaN             60.0         81.699997
# 1                      NaN             61.0         94.800003
# 2                      NaN             43.0         96.000000
# 3                      NaN             56.0        110.800003
# 4                      NaN             75.0        114.800003
#
#    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 0           84.300003          182.500000            189.000000
# 1           97.900002          176.100006            179.399994
# 2           97.699997          241.899994            244.100006
# 3          113.300003          216.199997            224.000000
# 4          118.699997          211.399994            215.600006
#
#    SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 0            7226362.5              7456910.0      2003882.00
# 1            8387933.0              8664479.0            0.00
# 2           72587024.0             73937112.0     21566554.00
# 3            6794584.0              6946800.5      2214446.25
# 4           14172606.0             14656503.0            0.00
#
#    Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  \
# 0      1.156514e+06          3946027.0         12764.52930         1276453.0
# 1      9.504252e+05          3242851.0         51450.81641         5145082.0
# 2      1.451544e+07         49526664.0         14938.00000         1493800.0
# 3      8.115253e+05          2768924.0         18112.13086         1811213.0
# 4      1.573449e+06          5368607.0         88039.98438         8803998.0
#
#    DefaultData  Comments ComplianceStatus Outlier  TotalGHGEmissions  \
# 0        False       NaN        Compliant     NaN             249.98
# 1        False       NaN        Compliant     NaN             295.86
# 2        False       NaN        Compliant     NaN            2089.28
# 3        False       NaN        Compliant     NaN             286.43
# 4        False       NaN        Compliant     NaN             505.01
#
#    GHGEmissionsIntensity
# 0                   2.83
# 1                   2.86
# 2                   2.19
# 3                   4.67
# 4                   2.88

# %%
df_2016.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus',
#        'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype='object')

# %%
df_2015.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
#        'GHGEmissions(MetricTonsCO2e)', 'GHGEmissionsIntensity(kgCO2e/ft2)',
#        'DefaultData', 'Comment', 'ComplianceStatus', 'Outlier',
#        '2010 Census Tracts',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'City Council Districts', 'SPD Beats', 'Zip Codes'],
#       dtype='object')

# %%
print(df_2016.shape)
print(df_2015.shape)
# Out:
# (3376, 46)
# (3340, 47)

# %%
plt.figure()
msno.bar(df_2016.sample(1000))
plt.title('df_2016')
plt.figure()
plt.title('df_2015')
msno.bar(df_2015.sample(1000))

# %%
df_2016["Outlier"].value_counts(normalize=False)#.plot(kind='pie')
# Out:
# Low outlier     23
# High outlier     9
# Name: Outlier, dtype: int64

# %%
df_2016.shape
# Out:
# (3376, 46)

# %%
df_2015.shape
# Out:
# (3340, 47)

# %% [markdown]
# #### Supprimer les outliers

# %%
df_2016 = df_2016.loc[df_2016["Outlier"] != "Low outlier"]
df_2016 = df_2016.loc[df_2016["Outlier"] != "High outlier"]
df_2015 = df_2015.loc[df_2015["Outlier"] != "Low outlier"]
df_2015 = df_2015.loc[df_2015["Outlier"] != "High outlier"]

# %%
df_2016.shape
# Out:
# (3344, 46)

# %%
df_2015.shape
# Out:
# (3340, 47)

# %%
df_2016['Outlier']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3371    NaN
# 3372    NaN
# 3373    NaN
# 3374    NaN
# 3375    NaN
# Name: Outlier, Length: 3344, dtype: object

# %%
df_2015['Outlier']
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3       High Outlier
# 4                NaN
#             ...
# 3335             NaN
# 3336             NaN
# 3337             NaN
# 3338             NaN
# 3339             NaN
# Name: Outlier, Length: 3340, dtype: object

# %% [markdown]
# #### Supprimer les colonnes qui ont 80% de données manquantes

# %%
df_2016 = df_2016[df_2016.columns[df_2016.isna().sum()/df_2016.shape[0] < 0.8]]
df_2015 = df_2015[df_2015.columns[df_2015.isna().sum()/df_2015.shape[0] < 0.8]]

# %%
df_2016.shape
# Out:
# (3344, 41)

# %%
df_2015.shape
# Out:
# (3340, 40)

# %%
plt.figure()
msno.bar(df_2016.sample(1000))
plt.title('df_2016')
plt.figure('df_2015')
msno.bar(df_2015.sample(1000))

# %%
print('Colonnes présentes sur données 2015 et absentes sur 2016 : \n', set(df_2015.columns) - set(df_2016.columns))
print('\nColonnes présentes sur données 2016 et absentes sur 2015 : \n', set(df_2016.columns) - set(df_2015.columns))
# Out:
# Colonnes présentes sur données 2015 et absentes sur 2016 :
#  {'Location', 'GHGEmissionsIntensity(kgCO2e/ft2)', 'Seattle Police Department Micro Community Policing Plan Areas', 'SPD Beats', 'GHGEmissions(MetricTonsCO2e)', 'OtherFuelUse(kBtu)', 'Zip Codes'}
#
# Colonnes présentes sur données 2016 et absentes sur 2015 :
#  {'GHGEmissionsIntensity', 'State', 'Latitude', 'TotalGHGEmissions', 'Address', 'City', 'Longitude', 'ZipCode'}

# %% [markdown]
# #### Récupérer les données dans la colonne location

# %%
import ast
import json  
from pandas.io.json import json_normalize

def transform_columns (dataframe):

        
    #ajout des informations des colonnes manquantes
    location = pd.DataFrame()
    for line, building_id in zip(df_2015['Location'], df_2015['OSEBuildingID']):
        line = ast.literal_eval(line)
        line = json_normalize(line)
        
        latitude = line['latitude'][0]
        longitude = line['longitude'][0]

        line = pd.DataFrame(ast.literal_eval(line['human_address'][0]), index=[0])
        location = pd.concat([location,
                             pd.DataFrame({
                       'Building_id' : building_id,
                       'Address' : line['address'][0],
                       'City' : line['city'][0],
                       'State' : line['state'][0],
                       'ZipCode' : line['zip'][0],
                       'Latitude' : latitude,
                       'Longitude': longitude }, index=[0])],
                             axis=0)
    return pd.merge(dataframe, location, left_on = 'OSEBuildingID', 
                    right_on = 'Building_id').drop(['Building_id','Location'],axis=1)

# %%
df_2015 = transform_columns(df_2015)
# Out:
# <ipython-input-66-ef3af0c7a75e>:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   line = json_normalize(line)

# %%
print('colonnes présentes sur données 2015 et absentes sur 2016 : \n', set(df_2015.columns) - set(df_2016.columns))
print('\ncolonnes présentes sur données 2016 et absentes sur 2015 : \n', set(df_2016.columns) - set(df_2015.columns))
# Out:
# colonnes présentes sur données 2015 et absentes sur 2016 :
#  {'GHGEmissionsIntensity(kgCO2e/ft2)', 'Seattle Police Department Micro Community Policing Plan Areas', 'SPD Beats', 'GHGEmissions(MetricTonsCO2e)', 'OtherFuelUse(kBtu)', 'Zip Codes'}
#
# colonnes présentes sur données 2016 et absentes sur 2015 :
#  {'GHGEmissionsIntensity', 'TotalGHGEmissions'}

# %% [markdown]
# #### Exploration des deux variables qui restent (totalGHGEmission & GHGEmissionsIntensity)

# %%
pd.set_option('display.max_columns', 50)

# %%
df_2016['GHGEmissionsIntensity']
# Out:
# 0        2.83
# 1        2.86
# 2        2.19
# 3        4.67
# 4        2.88
#         ...
# 3371     1.70
# 3372     2.01
# 3373    16.99
# 3374     1.57
# 3375     2.26
# Name: GHGEmissionsIntensity, Length: 3344, dtype: float64

# %%
df_2016['TotalGHGEmissions']
# Out:
# 0        249.98
# 1        295.86
# 2       2089.28
# 3        286.43
# 4        505.01
#          ...
# 3371      20.94
# 3372      32.17
# 3373     223.54
# 3374      22.11
# 3375      41.27
# Name: TotalGHGEmissions, Length: 3344, dtype: float64

# %%
df_2015['GHGEmissionsIntensity(kgCO2e/ft2)']
# Out:
# 0        2.64
# 1        2.38
# 2        1.92
# 3       31.38
# 4        4.02
#         ...
# 3335     0.07
# 3336     0.61
# 3337     1.89
# 3338     0.04
# 3339     0.05
# Name: GHGEmissionsIntensity(kgCO2e/ft2), Length: 3340, dtype: float64

# %%
df_2015['GHGEmissions(MetricTonsCO2e)']
# Out:
# 0        249.43
# 1        263.51
# 2       2061.48
# 3       1936.34
# 4        507.70
#          ...
# 3335       7.97
# 3336      30.69
# 3337     627.97
# 3338       5.42
# 3339       6.74
# Name: GHGEmissions(MetricTonsCO2e), Length: 3340, dtype: float64

# %%
plt.figure
plt.plot(df_2016['GHGEmissionsIntensity'])
plt.plot(df_2015['GHGEmissionsIntensity(kgCO2e/ft2)'])

# %%
plt.figure
plt.plot(df_2016['TotalGHGEmissions'])
plt.plot(df_2015['GHGEmissions(MetricTonsCO2e)'])

# %% [markdown]
# #### rassembler les deux variables au nom correspondant

# %%
df_2015['TotalGHGEmissions'] = df_2015['GHGEmissions(MetricTonsCO2e)']
df_2015['GHGEmissionsIntensity'] = df_2015['GHGEmissionsIntensity(kgCO2e/ft2)']
df_2015.drop(['GHGEmissions(MetricTonsCO2e)', 'GHGEmissionsIntensity(kgCO2e/ft2)'], axis=1, inplace=True)

# %%
df_2015.shape
# Out:
# (3340, 45)

# %%
df_2016.shape
# Out:
# (3344, 41)

# %%
print('colonnes présentes sur données 2015 et absentes sur 2016 : \n', set(df_2015.columns) - set(df_2016.columns))
print('\ncolonnes présentes sur données 2016 et absentes sur 2015 : \n', set(df_2016.columns) - set(df_2015.columns))
# Out:
# colonnes présentes sur données 2015 et absentes sur 2016 :
#  {'SPD Beats', 'Seattle Police Department Micro Community Policing Plan Areas', 'OtherFuelUse(kBtu)', 'Zip Codes'}
#
# colonnes présentes sur données 2016 et absentes sur 2015 :
#  set()

# %%
df_2015 = df_2015.drop(['OtherFuelUse(kBtu)','Zip Codes','SPD Beats','Seattle Police Department Micro Community Policing Plan Areas'],axis=1)

# %%
print('colonnes présentes sur données 2015 et absentes sur 2016 : \n', set(df_2015.columns) - set(df_2016.columns))
print('\ncolonnes présentes sur données 2016 et absentes sur 2015 : \n', set(df_2016.columns) - set(df_2015.columns))
# Out:
# colonnes présentes sur données 2015 et absentes sur 2016 :
#  set()
#
# colonnes présentes sur données 2016 et absentes sur 2015 :
#  set()

# %% [markdown]
# ###### Vérifier que les deux DF ont les mêmes dtypes

# %%
pd.DataFrame([df_2015.dtypes, df_2016.dtypes])
# Out:
#   OSEBuildingID DataYear BuildingType PrimaryPropertyType PropertyName  \
# 0         int64    int64       object              object       object
# 1         int64    int64       object              object       object
#
#   TaxParcelIdentificationNumber CouncilDistrictCode Neighborhood YearBuilt  \
# 0                        object               int64       object     int64
# 1                        object               int64       object     int64
#
#   NumberofBuildings NumberofFloors PropertyGFATotal PropertyGFAParking  \
# 0             int64        float64            int64              int64
# 1           float64          int64            int64              int64
#
#   PropertyGFABuilding(s) ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 0                  int64                    object                 object
# 1                  int64                    object                 object
#
#   LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0                   float64                       object
# 1                   float64                       object
#
#   SecondLargestPropertyUseTypeGFA ENERGYSTARScore SiteEUI(kBtu/sf)  \
# 0                         float64         float64          float64
# 1                         float64         float64          float64
#
#   SiteEUIWN(kBtu/sf) SourceEUI(kBtu/sf) SourceEUIWN(kBtu/sf)  \
# 0            float64            float64              float64
# 1            float64            float64              float64
#
#   SiteEnergyUse(kBtu) SiteEnergyUseWN(kBtu) SteamUse(kBtu) Electricity(kWh)  \
# 0             float64               float64        float64          float64
# 1             float64               float64        float64          float64
#
#   Electricity(kBtu) NaturalGas(therms) NaturalGas(kBtu) DefaultData  \
# 0           float64            float64          float64      object
# 1           float64            float64          float64        bool
#
#   ComplianceStatus Address    City   State  ZipCode Latitude Longitude  \
# 0           object  object  object  object   object   object    object
# 1           object  object  object  object  float64  float64   float64
#
#   TotalGHGEmissions GHGEmissionsIntensity
# 0           float64               float64
# 1           float64               float64

# %% [markdown]
# #### Regarder les colonnes avec des données différentes
#
# NumberofBuildings(int/float) / NumberofFloors(int/float) / DefaultData (objet/bool) / ZipCode (objet/float) /
# Latitude (objet/float) / Longitude (objet/float)

# %%
df_2015['NumberofBuildings']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3335    1
# 3336    1
# 3337    1
# 3338    1
# 3339    1
# Name: NumberofBuildings, Length: 3340, dtype: int64

# %%
df_2016['NumberofBuildings']
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 3371    1.0
# 3372    1.0
# 3373    1.0
# 3374    1.0
# 3375    1.0
# Name: NumberofBuildings, Length: 3344, dtype: float64

# %% [markdown]
# ###### Passer 2015 en float

# %%
df_2015['NumberofFloors']
# Out:
# 0       12.0
# 1       11.0
# 2       41.0
# 3       10.0
# 4       18.0
#         ...
# 3335     4.0
# 3336     7.0
# 3337    40.0
# 3338     3.0
# 3339     4.0
# Name: NumberofFloors, Length: 3340, dtype: float64

# %%
df_2016['NumberofFloors']
# Out:
# 0       12
# 1       11
# 2       41
# 3       10
# 4       18
#         ..
# 3371     1
# 3372     1
# 3373     1
# 3374     1
# 3375     1
# Name: NumberofFloors, Length: 3344, dtype: int64

# %% [markdown]
# ###### Passer 2015 en float

# %%
df_2015['DefaultData']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 3335     No
# 3336     No
# 3337     No
# 3338     No
# 3339     No
# Name: DefaultData, Length: 3340, dtype: object

# %%
df_2016['DefaultData']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3371     True
# 3372    False
# 3373    False
# 3374    False
# 3375    False
# Name: DefaultData, Length: 3344, dtype: bool

# %% [markdown]
# ###### Passer 2015 en bool

# %% [markdown]
# ###### ZipCode,Latitude,Longitude passés en float

# %%
df_2015[['Latitude','Longitude', 'ZipCode','NumberofBuildings']] = df_2015[['Latitude','Longitude', 'ZipCode','NumberofBuildings']].astype('float64')
df_2016[['NumberofFloors']] = df_2016[['NumberofFloors']].astype('float64')
#les 5 variables en float

# %%
df_2015['DefaultData'] = df_2015['DefaultData'].map({'Yes' : True , 'No' : False})

# %%
pd.DataFrame([df_2015.dtypes, df_2016.dtypes])
# Out:
#   OSEBuildingID DataYear BuildingType PrimaryPropertyType PropertyName  \
# 0         int64    int64       object              object       object
# 1         int64    int64       object              object       object
#
#   TaxParcelIdentificationNumber CouncilDistrictCode Neighborhood YearBuilt  \
# 0                        object               int64       object     int64
# 1                        object               int64       object     int64
#
#   NumberofBuildings NumberofFloors PropertyGFATotal PropertyGFAParking  \
# 0           float64        float64            int64              int64
# 1           float64        float64            int64              int64
#
#   PropertyGFABuilding(s) ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 0                  int64                    object                 object
# 1                  int64                    object                 object
#
#   LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0                   float64                       object
# 1                   float64                       object
#
#   SecondLargestPropertyUseTypeGFA ENERGYSTARScore SiteEUI(kBtu/sf)  \
# 0                         float64         float64          float64
# 1                         float64         float64          float64
#
#   SiteEUIWN(kBtu/sf) SourceEUI(kBtu/sf) SourceEUIWN(kBtu/sf)  \
# 0            float64            float64              float64
# 1            float64            float64              float64
#
#   SiteEnergyUse(kBtu) SiteEnergyUseWN(kBtu) SteamUse(kBtu) Electricity(kWh)  \
# 0             float64               float64        float64          float64
# 1             float64               float64        float64          float64
#
#   Electricity(kBtu) NaturalGas(therms) NaturalGas(kBtu) DefaultData  \
# 0           float64            float64          float64      object
# 1           float64            float64          float64        bool
#
#   ComplianceStatus Address    City   State  ZipCode Latitude Longitude  \
# 0           object  object  object  object  float64  float64   float64
# 1           object  object  object  object  float64  float64   float64
#
#   TotalGHGEmissions GHGEmissionsIntensity
# 0           float64               float64
# 1           float64               float64

# %% [markdown]
# #### Il n'y a plus de colonnes différentes on va pouvoir assembler les deux DF

# %%
df = pd.concat([df_2015, df_2016], axis=0, sort=False)

# %%
pd.set_option('display.max_columns',41)
pd.set_option('display.max_rows',41)

# %%
df['OSEBuildingID'].head(10)
# Out:
# 0     1
# 1     2
# 2     3
# 3     5
# 4     8
# 5     9
# 6    10
# 7    11
# 8    12
# 9    13
# Name: OSEBuildingID, dtype: int64

# %%
df.shape
# Out:
# (6684, 41)

# %% [markdown]
# #### Supprimer les duplicates

# %%
df.shape
# Out:
# (6684, 41)

# %%
df = df.drop_duplicates(subset=['OSEBuildingID'],keep='last')

# %%
df.shape
# Out:
# (3430, 41)

# %% [markdown]
# #### Eliminer les batiments residentiels (consigne)

# %%
df['BuildingType'].unique()             #supprime multifamily
# Out:
# array(['Multifamily LR (1-4)', 'NonResidential', 'Multifamily HR (10+)',
#        'SPS-District K-12', 'Multifamily MR (5-9)', 'Nonresidential COS',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %%
df = df[(df['BuildingType'] != 'Multifamily MR (5-9)') & (df['BuildingType']!='Multifamily HR (10+)')& (df['BuildingType']!='Multifamily LR (1-4)')]

# %%
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'SPS-District K-12', 'Nonresidential COS',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %%
df.shape
# Out:
# (1698, 41)

# %% [markdown]
# #### Erreur d'écriture (minimiser le nombre de valeurs dans les colonnes)

# %%
for col in df:    
    effectifs = df[col].value_counts()
    modalites = effectifs.index # l'index de effectifs contient les modalités

    tab = pd.DataFrame(modalites, columns = [col]) # création du tableau à partir des modalités
    tab["n"] = effectifs.values
    tab["f"] = tab["n"] / len(df) # len(data) renvoie la taille de l'échantillon
    print(tab)
    print('\n')
# Out:
#       OSEBuildingID  n         f
# 0             49865  1  0.000589
# 1             25670  1  0.000589
# 2             27721  1  0.000589
# 3             25674  1  0.000589
# 4             21580  1  0.000589
# ...             ... ..       ...
# 1693            543  1  0.000589
# 1694            545  1  0.000589
# 1695            547  1  0.000589
# 1696          23076  1  0.000589
# 1697              2  1  0.000589
#
# [1698 rows x 3 columns]
#
#
#    DataYear     n        f
# 0      2016  1651  0.97232
# 1      2015    47  0.02768
#
#
#          BuildingType     n         f
# 0      NonResidential  1488  0.876325
# 1   SPS-District K-12    99  0.058304
# 2  Nonresidential COS    85  0.050059
# 3              Campus    25  0.014723
# 4   Nonresidential WA     1  0.000589
#
#
#             PrimaryPropertyType    n         f
# 0   Small- and Mid-Sized Office  298  0.175501
# 1                         Other  257  0.151355
# 2                     Warehouse  187  0.110130
# 3                  Large Office  176  0.103651
# 4                   K-12 School  141  0.083039
# 5            Mixed Use Property  115  0.067727
# 6                  Retail Store   94  0.055359
# 7                         Hotel   76  0.044759
# 8              Worship Facility   72  0.042403
# 9           Distribution Center   53  0.031213
# 10               Medical Office   42  0.024735
# 11  Supermarket / Grocery Store   40  0.023557
# 12        Self-Storage Facility   28  0.016490
# 13                   University   24  0.014134
# 14               Residence Hall   21  0.012367
# 15        Senior Care Community   20  0.011779
# 16                   Restaurant   12  0.007067
# 17       Refrigerated Warehouse   12  0.007067
# 18                   Laboratory   10  0.005889
# 19                     Hospital   10  0.005889
# 20                       Office    3  0.001767
# 21   Non-Refrigerated Warehouse    3  0.001767
# 22         Low-Rise Multifamily    3  0.001767
# 23                 Restaurant\n    1  0.000589
#
#
#                             PropertyName  n         f
# 0                       Bayview Building  2  0.001178
# 1                         Canal Building  2  0.001178
# 2                            Airport Way  2  0.001178
# 3                             South Park  2  0.001178
# 4           645 Elliott - North Building  1  0.000589
# ...                                  ... ..       ...
# 1689  Washington State Convention Center  1  0.000589
# 1690                         Hays Elliot  1  0.000589
# 1691                    Skinner Building  1  0.000589
# 1692                   The Peck Building  1  0.000589
# 1693            W000252-NORTH SEATTLE WA  1  0.000589
#
# [1694 rows x 3 columns]
#
#
#      TaxParcelIdentificationNumber  n         f
# 0                       1625049001  8  0.004711
# 1                       3224049012  5  0.002945
# 2                       0925049346  5  0.002945
# 3                       3624039009  4  0.002356
# 4                       7666203240  4  0.002356
# ...                            ... ..       ...
# 1610                    1975700195  1  0.000589
# 1611                    1976200060  1  0.000589
# 1612                    1985200090  1  0.000589
# 1613                    4206900485  1  0.000589
# 1614                    7666207420  1  0.000589
#
# [1615 rows x 3 columns]
#
#
#    CouncilDistrictCode    n         f
# 0                    7  543  0.319788
# 1                    2  403  0.237338
# 2                    3  208  0.122497
# 3                    4  173  0.101885
# 4                    5  135  0.079505
# 5                    1  119  0.070082
# 6                    6  117  0.068905
#
#
#               Neighborhood    n         f
# 0                 DOWNTOWN  370  0.217903
# 1         GREATER DUWAMISH  349  0.205536
# 2    MAGNOLIA / QUEEN ANNE  155  0.091284
# 3               LAKE UNION  151  0.088928
# 4                NORTHEAST  128  0.075383
# 5                     EAST  125  0.073616
# 6                NORTHWEST   84  0.049470
# 7                  BALLARD   66  0.038869
# 8                    NORTH   58  0.034158
# 9                  CENTRAL   51  0.030035
# 10               SOUTHEAST   48  0.028269
# 11                DELRIDGE   42  0.024735
# 12               SOUTHWEST   41  0.024146
# 13                   North    9  0.005300
# 14                 Ballard    6  0.003534
# 15               Northwest    5  0.002945
# 16                 Central    5  0.002945
# 17                Delridge    4  0.002356
# 18  DELRIDGE NEIGHBORHOODS    1  0.000589
#
#
#      YearBuilt   n         f
# 0         1900  47  0.027680
# 1         2000  35  0.020612
# 2         1970  33  0.019435
# 3         1910  31  0.018257
# 4         1979  30  0.017668
# ..         ...  ..       ...
# 108       1939   2  0.001178
# 109       1944   2  0.001178
# 110       1901   2  0.001178
# 111       1936   1  0.000589
# 112       1935   1  0.000589
#
# [113 rows x 3 columns]
#
#
#     NumberofBuildings     n         f
# 0                 1.0  1591  0.936985
# 1                 0.0    52  0.030624
# 2                 2.0    14  0.008245
# 3                 3.0    12  0.007067
# 4                 5.0     7  0.004122
# 5                 6.0     4  0.002356
# 6                 4.0     4  0.002356
# 7                 8.0     2  0.001178
# 8                14.0     2  0.001178
# 9                 7.0     2  0.001178
# 10              111.0     1  0.000589
# 11               10.0     1  0.000589
# 12               23.0     1  0.000589
# 13                9.0     1  0.000589
# 14               11.0     1  0.000589
# 15               27.0     1  0.000589
#
#
#     NumberofFloors    n         f
# 0              1.0  473  0.278563
# 1              2.0  399  0.234982
# 2              3.0  274  0.161366
# 3              4.0  151  0.088928
# 4              5.0  103  0.060660
# ..             ...  ...       ...
# 40            39.0    1  0.000589
# 41            63.0    1  0.000589
# 42            37.0    1  0.000589
# 43            28.0    1  0.000589
# 44            99.0    1  0.000589
#
# [45 rows x 3 columns]
#
#
#       PropertyGFATotal  n         f
# 0                21600  8  0.004711
# 1                36000  7  0.004122
# 2                25920  7  0.004122
# 3                28800  7  0.004122
# 4                24000  5  0.002945
# ...                ... ..       ...
# 1611             92792  1  0.000589
# 1612             60696  1  0.000589
# 1613             23166  1  0.000589
# 1614            170632  1  0.000589
# 1615             47105  1  0.000589
#
# [1616 rows x 3 columns]
#
#
#      PropertyGFAParking     n         f
# 0                     0  1357  0.799176
# 1                 13320     3  0.001767
# 2                 30000     2  0.001178
# 3                100176     2  0.001178
# 4                 10800     2  0.001178
# ..                  ...   ...       ...
# 329              114010     1  0.000589
# 330              154972     1  0.000589
# 331               52582     1  0.000589
# 332              101342     1  0.000589
# 333               85028     1  0.000589
#
# [334 rows x 3 columns]
#
#
#       PropertyGFABuilding(s)  n         f
# 0                      21600  8  0.004711
# 1                      25920  7  0.004122
# 2                      36000  7  0.004122
# 3                      28800  7  0.004122
# 4                      24000  5  0.002945
# ...                      ... ..       ...
# 1606                 1172127  1  0.000589
# 1607                   49825  1  0.000589
# 1608                   55974  1  0.000589
# 1609                   93555  1  0.000589
# 1610                   47105  1  0.000589
#
# [1611 rows x 3 columns]
#
#
#                              ListOfAllPropertyUseTypes    n         f
# 0                                               Office  144  0.084806
# 1                                          K-12 School  137  0.080683
# 2                                      Office, Parking  122  0.071849
# 3                           Non-Refrigerated Warehouse  101  0.059482
# 4                                                Other   62  0.036514
# ..                                                 ...  ...       ...
# 373  Other - Education, Performing Arts, Social/Mee...    1  0.000589
# 374  Non-Refrigerated Warehouse, Office, Other, Oth...    1  0.000589
# 375                     College/University, Restaurant    1  0.000589
# 376  Multifamily Housing, Non-Refrigerated Warehous...    1  0.000589
# 377  Distribution Center, Non-Refrigerated Warehous...    1  0.000589
#
# [378 rows x 3 columns]
#
#
#                                LargestPropertyUseType    n         f
# 0                                              Office  506  0.297998
# 1                          Non-Refrigerated Warehouse  200  0.117786
# 2                                         K-12 School  141  0.083039
# 3                                               Other  101  0.059482
# 4                                        Retail Store  100  0.058893
# ..                                                ...  ...       ...
# 52                                       Fire Station    1  0.000589
# 53  Personal Services (Health/Beauty, Dry Cleaning...    1  0.000589
# 54                                         Courthouse    1  0.000589
# 55         Outpatient Rehabilitation/Physical Therapy    1  0.000589
# 56                                     Police Station    1  0.000589
#
# [57 rows x 3 columns]
#
#
#       LargestPropertyUseTypeGFA  n         f
# 0                       24000.0  6  0.003534
# 1                       21600.0  6  0.003534
# 2                       30000.0  6  0.003534
# 3                       22000.0  5  0.002945
# 4                       25000.0  5  0.002945
# ...                         ... ..       ...
# 1577                   483520.0  1  0.000589
# 1578                    49334.0  1  0.000589
# 1579                    75605.0  1  0.000589
# 1580                    25946.0  1  0.000589
# 1581                   217088.0  1  0.000589
#
# [1582 rows x 3 columns]
#
#
#                          SecondLargestPropertyUseType    n         f
# 0                                             Parking  342  0.201413
# 1                                              Office  169  0.099529
# 2                                        Retail Store   86  0.050648
# 3                                               Other   45  0.026502
# 4                          Non-Refrigerated Warehouse   30  0.017668
# ..                                                ...  ...       ...
# 42                                 Pre-school/Daycare    1  0.000589
# 43                                         Courthouse    1  0.000589
# 44                                   Financial Office    1  0.000589
# 45  Personal Services (Health/Beauty, Dry Cleaning...    1  0.000589
# 46                                  Vocational School    1  0.000589
#
# [47 rows x 3 columns]
#
#
#      SecondLargestPropertyUseTypeGFA   n         f
# 0                                0.0  81  0.047703
# 1                            15000.0  10  0.005889
# 2                             5000.0   8  0.004711
# 3                             7000.0   7  0.004122
# 4                             7200.0   6  0.003534
# ..                               ...  ..       ...
# 703                          53971.0   1  0.000589
# 704                          15212.0   1  0.000589
# 705                           6165.0   1  0.000589
# 706                           5826.0   1  0.000589
# 707                          27427.0   1  0.000589
#
# [708 rows x 3 columns]
#
#
#     ENERGYSTARScore   n         f
# 0             100.0  39  0.022968
# 1              89.0  28  0.016490
# 2              98.0  28  0.016490
# 3              95.0  27  0.015901
# 4              96.0  24  0.014134
# ..              ...  ..       ...
# 95              4.0   3  0.001767
# 96             13.0   3  0.001767
# 97             28.0   3  0.001767
# 98             11.0   3  0.001767
# 99             24.0   3  0.001767
#
# [100 rows x 3 columns]
#
#
#      SiteEUI(kBtu/sf)   n         f
# 0            0.000000  15  0.008834
# 1           52.700001   7  0.004122
# 2           30.900000   7  0.004122
# 3           35.000000   7  0.004122
# 4           44.000000   6  0.003534
# ..                ...  ..       ...
# 989         17.299999   1  0.000589
# 990         37.500000   1  0.000589
# 991        125.599999   1  0.000589
# 992         40.500000   1  0.000589
# 993         23.500000   1  0.000589
#
# [994 rows x 3 columns]
#
#
#       SiteEUIWN(kBtu/sf)   n         f
# 0               0.000000  26  0.015312
# 1              33.599998   6  0.003534
# 2              52.299999   6  0.003534
# 3              48.799999   5  0.002945
# 4              46.400002   5  0.002945
# ...                  ...  ..       ...
# 999            16.400000   1  0.000589
# 1000          219.399994   1  0.000589
# 1001          111.699997   1  0.000589
# 1002           82.699997   1  0.000589
# 1003           16.200001   1  0.000589
#
# [1004 rows x 3 columns]
#
#
#       SourceEUI(kBtu/sf)   n         f
# 0               0.000000  18  0.010601
# 1              94.099998   5  0.002945
# 2              59.000000   5  0.002945
# 3             125.400001   5  0.002945
# 4              58.000000   5  0.002945
# ...                  ...  ..       ...
# 1293          296.799988   1  0.000589
# 1294          175.399994   1  0.000589
# 1295           66.300003   1  0.000589
# 1296         1080.200000   1  0.000589
# 1297          207.500000   1  0.000589
#
# [1298 rows x 3 columns]
#
#
#       SourceEUIWN(kBtu/sf)   n         f
# 0                 0.000000  29  0.017079
# 1               107.000000   4  0.002356
# 2               145.500000   4  0.002356
# 3               135.100006   4  0.002356
# 4               151.800003   4  0.002356
# ...                    ...  ..       ...
# 1329            165.399994   1  0.000589
# 1330            293.399994   1  0.000589
# 1331            188.800003   1  0.000589
# 1332            222.899994   1  0.000589
# 1333            159.199997   1  0.000589
#
# [1334 rows x 3 columns]
#
#
#       SiteEnergyUse(kBtu)   n         f
# 0            0.000000e+00  16  0.009423
# 1            2.671351e+05   1  0.000589
# 2            1.231546e+06   1  0.000589
# 3            5.155568e+06   1  0.000589
# 4            8.476183e+06   1  0.000589
# ...                   ...  ..       ...
# 1675         3.372934e+07   1  0.000589
# 1676         5.761741e+05   1  0.000589
# 1677         1.987935e+06   1  0.000589
# 1678         1.145536e+06   1  0.000589
# 1679         3.481728e+06   1  0.000589
#
# [1680 rows x 3 columns]
#
#
#       SiteEnergyUseWN(kBtu)   n         f
# 0              0.000000e+00  26  0.015312
# 1              2.127889e+06   2  0.001178
# 2              7.469056e+05   1  0.000589
# 3              9.639682e+05   1  0.000589
# 4              7.711758e+06   1  0.000589
# ...                     ...  ..       ...
# 1663           2.382550e+05   1  0.000589
# 1664           1.000549e+07   1  0.000589
# 1665           1.529218e+06   1  0.000589
# 1666           1.131634e+07   1  0.000589
# 1667           1.781798e+06   1  0.000589
#
# [1668 rows x 3 columns]
#
#
#      SteamUse(kBtu)     n         f
# 0      0.000000e+00  1579  0.929918
# 1      7.625423e+05     1  0.000589
# 2      1.639341e+06     1  0.000589
# 3      8.156761e+05     1  0.000589
# 4      2.309893e+05     1  0.000589
# ..              ...   ...       ...
# 112    3.593940e+06     1  0.000589
# 113    7.489847e+05     1  0.000589
# 114    6.090188e+06     1  0.000589
# 115    5.482947e+05     1  0.000589
# 116    2.123080e+04     1  0.000589
#
# [117 rows x 3 columns]
#
#
#       Electricity(kWh)   n         f
# 0         0.000000e+00  11  0.006478
# 1         2.390116e+05   2  0.001178
# 2         1.198617e+06   1  0.000589
# 3         3.576907e+06   1  0.000589
# 4         3.733872e+05   1  0.000589
# ...                ...  ..       ...
# 1679      1.190574e+07   1  0.000589
# 1680      1.622399e+06   1  0.000589
# 1681      1.471839e+06   1  0.000589
# 1682      8.833767e+05   1  0.000589
# 1683      1.498000e+05   1  0.000589
#
# [1684 rows x 3 columns]
#
#
#       Electricity(kBtu)   n         f
# 0                   0.0  11  0.006478
# 1              815508.0   2  0.001178
# 2             2606839.0   1  0.000589
# 3              910718.0   1  0.000589
# 4             1436416.0   1  0.000589
# ...                 ...  ..       ...
# 1679          2403347.0   1  0.000589
# 1680          2094607.0   1  0.000589
# 1681          1398289.0   1  0.000589
# 1682           171716.0   1  0.000589
# 1683           981009.0   1  0.000589
#
# [1684 rows x 3 columns]
#
#
#       NaturalGas(therms)    n         f
# 0               0.000000  486  0.286219
# 1            2268.460205    2  0.001178
# 2           40741.800780    1  0.000589
# 3          179475.718800    1  0.000589
# 4          114925.031300    1  0.000589
# ...                  ...  ...       ...
# 1204         3341.709961    1  0.000589
# 1205        32935.761720    1  0.000589
# 1206        43282.667970    1  0.000589
# 1207        17471.160160    1  0.000589
# 1208        11058.710940    1  0.000589
#
# [1209 rows x 3 columns]
#
#
#       NaturalGas(kBtu)    n         f
# 0                  0.0  486  0.286219
# 1             226846.0    2  0.001178
# 2             914084.0    1  0.000589
# 3             815770.0    1  0.000589
# 4            3154333.0    1  0.000589
# ...                ...  ...       ...
# 1204          757062.0    1  0.000589
# 1205          195410.0    1  0.000589
# 1206          286373.0    1  0.000589
# 1207          191828.0    1  0.000589
# 1208         2330615.0    1  0.000589
#
# [1209 rows x 3 columns]
#
#
#   DefaultData     n         f
# 0       False  1603  0.944052
# 1        True    95  0.055948
#
#
#                ComplianceStatus     n         f
# 0                     Compliant  1595  0.939340
# 1  Error - Correct Default Data    86  0.050648
# 2                  Missing Data    14  0.008245
# 3                 Non-Compliant     3  0.001767
#
#
#                           Address  n         f
# 0     309 South Cloverdale Street  4  0.002356
# 1              2203 Airport Way S  4  0.002356
# 2               2600 SW Barton St  4  0.002356
# 3                   516 1st Ave W  2  0.001178
# 4                10510 5th Ave NE  2  0.001178
# ...                           ... ..       ...
# 1672             1200 Harvard Ave  1  0.000589
# 1673       12537 Lake CIty Way NE  1  0.000589
# 1674         206 Western Ave West  1  0.000589
# 1675               1200 4TH AVE S  1  0.000589
# 1676       820 South Adams Street  1  0.000589
#
# [1677 rows x 3 columns]
#
#
#       City     n        f
# 0  Seattle  1651  0.97232
# 1  SEATTLE    47  0.02768
#
#
#   State     n    f
# 0    WA  1698  1.0
#
#
#     ZipCode    n         f
# 0   98134.0  184  0.108363
# 1   98104.0  161  0.094817
# 2   98101.0  154  0.090695
# 3   98109.0  145  0.085395
# 4   98108.0  120  0.070671
# ..      ...  ...       ...
# 43  98185.0    1  0.000589
# 44  98191.0    1  0.000589
# 45  98006.0    1  0.000589
# 46  98011.0    1  0.000589
# 47  98053.0    1  0.000589
#
# [48 rows x 3 columns]
#
#
#       Latitude  n         f
# 0     47.66246  9  0.005300
# 1     47.62208  6  0.003534
# 2     47.52549  5  0.002945
# 3     47.60427  4  0.002356
# 4     47.58290  4  0.002356
# ...        ... ..       ...
# 1524  47.67783  1  0.000589
# 1525  47.55066  1  0.000589
# 1526  47.59280  1  0.000589
# 1527  47.52190  1  0.000589
# 1528  47.60923  1  0.000589
#
# [1529 rows x 3 columns]
#
#
#        Longitude  n         f
# 0    -122.298980  8  0.004711
# 1    -122.353980  7  0.004122
# 2    -122.333690  5  0.002945
# 3    -122.333790  5  0.002945
# 4    -122.330640  5  0.002945
# ...          ... ..       ...
# 1438 -122.284630  1  0.000589
# 1439 -122.340188  1  0.000589
# 1440 -122.390750  1  0.000589
# 1441 -122.382380  1  0.000589
# 1442 -122.354890  1  0.000589
#
# [1443 rows x 3 columns]
#
#
#       TotalGHGEmissions  n         f
# 0                  0.00  6  0.003534
# 1                  6.30  3  0.001767
# 2                 41.80  2  0.001178
# 3                  8.80  2  0.001178
# 4                 30.22  2  0.001178
# ...                 ... ..       ...
# 1618             384.27  1  0.000589
# 1619              92.45  1  0.000589
# 1620             108.05  1  0.000589
# 1621              36.43  1  0.000589
# 1622              49.25  1  0.000589
#
# [1623 rows x 3 columns]
#
#
#      GHGEmissionsIntensity   n         f
# 0                     0.23  21  0.012367
# 1                     0.28  20  0.011779
# 2                     0.22  18  0.010601
# 3                     0.33  18  0.010601
# 4                     0.27  17  0.010012
# ..                     ...  ..       ...
# 461                  10.54   1  0.000589
# 462                   2.62   1  0.000589
# 463                   4.41   1  0.000589
# 464                   5.02   1  0.000589
# 465                   2.29   1  0.000589
#
# [466 rows x 3 columns]

# %%
df['Neighborhood'].replace('North', 'NORTH', inplace=True)
df['Neighborhood'].replace('CENTRAL', 'Central', inplace=True)
df['Neighborhood'].replace('Northwest', 'NORTHWEST', inplace=True)
df['Neighborhood'].replace('Ballard', 'BALLARD', inplace=True)
df['Neighborhood'].replace('DELRIDGE NEIGHBORHOODS', 'DELRIDGE', inplace=True)
df['Neighborhood'].replace('Delridge', 'DELRIDGE', inplace=True)
df['City'].replace('SEATTLE', 'Seattle', inplace=True)
df['ComplianceStatus'].replace('Error - Correct Default Data', np.nan, inplace=True)
df['ComplianceStatus'].replace('Not Compliant', 'Non-Compliant', inplace=True)
df['ComplianceStatus'].replace('Missing Data', np.nan, inplace=True)

# %% [markdown]
# #### Traiter les données manquantes

# %%
#Nombre de valeur manquante
def num_missing(df):
    return sum(df.isnull())
# On applique cette fonction pour chaque colonne:
print("Valeursmanquantes par colonne:")
print(df.apply(num_missing, axis=0))
# Out:
# Valeursmanquantes par colonne:
# OSEBuildingID                        0
# DataYear                             0
# BuildingType                         0
# PrimaryPropertyType                  0
# PropertyName                         0
# TaxParcelIdentificationNumber        1
# CouncilDistrictCode                  0
# Neighborhood                         0
# YearBuilt                            0
# NumberofBuildings                    2
# NumberofFloors                       1
# PropertyGFATotal                     0
# PropertyGFAParking                   0
# PropertyGFABuilding(s)               0
# ListOfAllPropertyUseTypes            9
# LargestPropertyUseType              13
# LargestPropertyUseTypeGFA           13
# SecondLargestPropertyUseType       833
# SecondLargestPropertyUseTypeGFA    833
# ENERGYSTARScore                    585
# SiteEUI(kBtu/sf)                     4
# SiteEUIWN(kBtu/sf)                   4
# SourceEUI(kBtu/sf)                   3
# SourceEUIWN(kBtu/sf)                 3
# SiteEnergyUse(kBtu)                  3
# SiteEnergyUseWN(kBtu)                4
# SteamUse(kBtu)                       3
# Electricity(kWh)                     3
# Electricity(kBtu)                    3
# NaturalGas(therms)                   3
# NaturalGas(kBtu)                     3
# DefaultData                          0
# ComplianceStatus                   100
# Address                              0
# City                                 0
# State                                0
# ZipCode                             16
# Latitude                             0
# Longitude                            0
# TotalGHGEmissions                    3
# GHGEmissionsIntensity                3
# dtype: int64

# %%
df = df.dropna(subset=['TotalGHGEmissions']) ### je veux absolument avoir cette information (targuet)
df = df.dropna(subset=['GHGEmissionsIntensity']) ### je veux absolument avoir cette information (targuet)
df = df.dropna(subset=['TaxParcelIdentificationNumber']) #juste 1 valeur manquante
df = df.dropna(subset=['SiteEUI(kBtu/sf)']) #juste 1 valeur manquante
df = df.dropna(subset=['SiteEUIWN(kBtu/sf)']) #juste 1 valeur manquante
df = df.dropna(subset=['NumberofFloors']) # 7 valeurs

# %%
df = df.drop(['ZipCode'],axis=1)      #colonne pas utilisable

# %%
df = df.dropna(subset=['TaxParcelIdentificationNumber'])

# %%
df = df.dropna(subset=['ListOfAllPropertyUseTypes']) # supprimer quand on n'a pas la donné
df['SecondLargestPropertyUseType'] = df['SecondLargestPropertyUseType'].fillna('no information') ## remplacer les non pas no informartion
df['LargestPropertyUseType'] = df['LargestPropertyUseType'].fillna('no information') #idem

# %%
df.shape
# Out:
# (1685, 40)

# %% [markdown]
# #### Remplacer les valeurs manquantes par un KNNImputer

# %%
from sklearn.impute import KNNImputer

# %%
data = df[['SecondLargestPropertyUseTypeGFA','ENERGYSTARScore','LargestPropertyUseTypeGFA']]

# %%
imputer = KNNImputer(n_neighbors=5)
imputer.fit_transform(data)
data = pd.DataFrame(imputer.fit_transform(data))

# %%
df.shape
# Out:
# (1685, 40)

# %%
df = df.drop(['SecondLargestPropertyUseTypeGFA','ENERGYSTARScore','LargestPropertyUseTypeGFA'],axis=1)

# %%
data = data.reset_index()
df = df.reset_index()

# %%
df = df.drop(['index'],axis=1)
data = data.drop(['index'],axis=1)

# %%
df = pd.concat([df, data],axis=1)

# %%
df.shape
# Out:
# (1685, 40)

# %%
df = df.rename(columns={0: "SecondLargestPropertyUseTypeGFA", 1: "ENERGYSTARScore",2:"LargestPropertyUseTypeGFA"})

# %% [markdown]
# #### Sauvegarder le dataframe

# %%
df.to_csv(r'C:/Users/Elisée/Desktop/P4/df.csv')
# dataframe de 1685 lines et 40 colonnes sans données manquantes.
